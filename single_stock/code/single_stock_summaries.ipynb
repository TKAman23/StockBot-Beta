# %% [markdown]
# # Single Stock Summary Generation
# ## Get Data

# %%
import os
import numpy as np
import pandas as pd
# Progress bar
from tqdm.notebook import tqdm as pbar
from tqdm.auto import tqdm as pdbar

# Pandas tqdm initialization
pdbar.pandas()

# Get rid of warnings 
import warnings

def set_index_no_warnings(df):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=UserWarning)
        warnings.simplefilter("ignore", category=FutureWarning)
        index = df.index.str.replace("—", "").str.replace("EST", "").str.strip()
        return pd.to_datetime(index, format="mixed").date


# Ticker
tick = "AAPL"

# Input ata directory
raw = "../news_raw"

# Load data
df = (
        pd.read_csv(
        os.path.join(raw, f"{tick.lower()}.csv"),
        index_col="Date",
        usecols=["Date", "Text"]
    )
    .rename(columns={"Text":"Article"})
    .query("index != 0 and index != '0'")
    .pipe(
        lambda df: df.set_index(
            set_index_no_warnings(df)
        )
    )
)

df
# Out:
#                                                       Article
# 2024-01-25  For Immediate Release\nChicago, IL – January 2...
# 2024-02-03  Thanks to its lineup of incredibly popular har...
# 2024-02-03  In this podcast, Motley Fool host Dylan Lewis ...
# 2024-02-03  Shares in Advanced Micro Devices (NASDAQ: AMD)...
# 2024-02-03  Investing in the stock market is one of the mo...
# ...                                                       ...
# 2024-02-03  In this podcast, Motley Fool host Dylan Lewis ...
# 2024-02-03  Shares in Advanced Micro Devices (NASDAQ: AMD)...
# 2024-02-03  Investing in the stock market is one of the mo...
# 2024-02-03  Since its price cratered 65% in 2022, Bitcoin ...
# 2024-02-03  China stocks got hit hard last month as a comb...
#
# [644 rows x 1 columns]

# %% [markdown]
# ## Summarization

# %%
# In the environment, run nltk.download("punkt") once if error is thrown
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.nlp.stemmers import Stemmer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sumy.summarizers.lex_rank import LexRankSummarizer

# Summary length in sentences:
summary_len = 13

# Summarizer initialization
summarizers = {
    "Lsa_summary":LsaSummarizer(Stemmer("english")),
    "Luhn_summary":LuhnSummarizer(Stemmer("english")),
    "Textrank_summary":TextRankSummarizer(Stemmer("english")),
    "Lexrank_summary":LexRankSummarizer(Stemmer("english"))
}

def summarize(text, date):
    # Parse article
    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    # Run through summarizers
    summaries = {name : bot(parser.document, summary_len) for name, bot in summarizers.items()}
    summaries["Date"] = date
    return summaries

# %%
# For parallel processing
from concurrent.futures import ThreadPoolExecutor

# Column names
summ_bots = ["Lsa_summary", "Luhn_summary", "Textrank_summary", "Lexrank_summary"]

# Keep things from crashing
def helper(text, date):
    try:
        return summarize(text, date)
    except Exception:
        print("ERROR ERROR ERROR")
        print(Exception)
        return {name : None for name in summ_bots}  # fallback

# Parallelize processing
with ThreadPoolExecutor(max_workers=4) as executor:
    results = list(executor.map(helper, df["Article"], df.index))

# Remove empty results
# Make dataframe of results
# Drop article column
cleaned = [result for result in results if result]
df = pd.concat([df.drop(columns=["Article"]), pd.DataFrame(cleaned).set_index("Date")], axis=1)

df
# Out:
#                                                   Lsa_summary  \
# 2024-01-25  (For Immediate Release Chicago, IL – January 2...
# 2024-02-03  (Maybe its turnaround plans could get a boost ...
# 2024-02-03  (Dylan Lewis: Bill, I love checking in on Micr...
# 2024-02-03  (Meanwhile, its free cash flow has plunged 47%...
# 2024-02-03  (The S&P 500 recently reached a new all-time h...
# ...                                                       ...
# 2024-02-03  (Dylan Lewis: Bill, I love checking in on Micr...
# 2024-02-03  (Meanwhile, its free cash flow has plunged 47%...
# 2024-02-03  (The S&P 500 recently reached a new all-time h...
# 2024-02-03  (Since its price cratered 65% in 2022, Bitcoin...
# 2024-02-03  (China stocks got hit hard last month as a com...
#
#                                                  Luhn_summary  \
# 2024-01-25  (For Immediate Release Chicago, IL – January 2...
# 2024-02-03  (Thanks to its lineup of incredibly popular ha...
# 2024-02-03  (It was a long road to becoming a $3 trillion ...
# 2024-02-03  (Shares in Advanced Micro Devices (NASDAQ: AMD...
# 2024-02-03  (Investing in the stock market is one of the m...
# ...                                                       ...
# 2024-02-03  (It was a long road to becoming a $3 trillion ...
# 2024-02-03  (Shares in Advanced Micro Devices (NASDAQ: AMD...
# 2024-02-03  (Investing in the stock market is one of the m...
# 2024-02-03  (Bullish investors are sure that there is a lo...
# 2024-02-03  (China stocks got hit hard last month as a com...
#
#                                              Textrank_summary  \
# 2024-01-25  (For Immediate Release Chicago, IL – January 2...
# 2024-02-03  (Thanks to its lineup of incredibly popular ha...
# 2024-02-03  (It was a long road to becoming a $3 trillion ...
# 2024-02-03  (The launch of OpenAI's ChatGPT in November 20...
# 2024-02-03  (Investing in the stock market is one of the m...
# ...                                                       ...
# 2024-02-03  (It was a long road to becoming a $3 trillion ...
# 2024-02-03  (The launch of OpenAI's ChatGPT in November 20...
# 2024-02-03  (Investing in the stock market is one of the m...
# 2024-02-03  (But it stands out among the tens of thousands...
# 2024-02-03  (China stocks got hit hard last month as a com...
#
#                                               Lexrank_summary
# 2024-01-25  (For Immediate Release Chicago, IL – January 2...
# 2024-02-03  (Thanks to its lineup of incredibly popular ha...
# 2024-02-03  (Andy Cross: Well, first on the news Dylan, an...
# 2024-02-03  (Shares in Advanced Micro Devices (NASDAQ: AMD...
# 2024-02-03  (Exchange-traded funds (ETFs) can be fantastic...
# ...                                                       ...
# 2024-02-03  (Andy Cross: Well, first on the news Dylan, an...
# 2024-02-03  (Shares in Advanced Micro Devices (NASDAQ: AMD...
# 2024-02-03  (Exchange-traded funds (ETFs) can be fantastic...
# 2024-02-03  (At a price of just over $43,000 as of Feb. 1,...
# 2024-02-03  (China stocks got hit hard last month as a com...
#
# [644 rows x 4 columns]

# %%
df.loc[pd.to_datetime("2024-01-25").date(), "Lsa_summary"]
# Out:
# 2024-01-25    (For Immediate Release Chicago, IL – January 2...
# 2024-01-25    (Given this, I can't help but remain bullish o...
# 2024-01-25    (But retail investors should pay close attenti...
# 2024-01-25    (Monster Beverage stock (NASDAQ:MNST) has prod...
# 2024-01-25    (The NASDAQ 100 After Hours Indicator is down ...
# 2024-01-25    ((RTTNews) - Apple Inc. (AAPL) introduced sign...
# 2024-01-25    ((RTTNews) - On Wednesday, Microsoft (MSFT) be...
# 2024-01-25    (Though consumer spending habits can shift sud...
# 2024-01-25    (Even prominent Tesla bull Dan Ives of Wedbush...
# 2024-01-25    (Alphabet Inc. Price and EPS Surprise Alphabet...
# 2024-01-25    (Comparing units outstanding versus one week a...
# 2024-01-25    (Apple (AAPL) is expected to deliver a year-ov...
# 2024-01-25    (With Apple (NASDAQ: AAPL) shares rising more ...
# 2024-01-25    (It will be remembered as the year artificial ...
# 2024-01-25    (Earnings are arguably the most important sing...
# 2024-01-25    (Bull of the Day: Apple stock ended 2023 and s...
# 2024-01-25    (Berkshire Hathaway CEO Warren Buffett used to...
# 2024-01-25    (Below is Validea's guru fundamental report fo...
# 2024-01-25    (Finding companies that have transformed a sim...
# 2024-01-25    (Further, growth stocks have a higher level of...
# 2024-01-25    (There are some investors, though, who think i...
# 2024-01-25    (The one area still showing growth is services...
# 2024-01-25    (For Immediate Release Chicago, IL – January 2...
# Name: Lsa_summary, dtype: object

# %%
# Sort values
df.sort_index(ascending=False, inplace=True)
df
# Out:
#                                                   Lsa_summary  \
# 2024-02-03  (China stocks got hit hard last month as a com...
# 2024-02-03  (Maybe its turnaround plans could get a boost ...
# 2024-02-03  (Since its price cratered 65% in 2022, Bitcoin...
# 2024-02-03  (The S&P 500 recently reached a new all-time h...
# 2024-02-03  (Meanwhile, its free cash flow has plunged 47%...
# ...                                                       ...
# 2023-12-19  (Each of the major market indexes has gained m...
# 2023-12-19  (Among the underlying components of the Russel...
# 2023-12-19  (Of the funds launched in 2023, 76% were activ...
# 2023-12-19  (Shiba Inu is still up just 25% for the year a...
# 2023-12-18  (This increasing enthusiasm has significantly ...
#
#                                                  Luhn_summary  \
# 2024-02-03  (China stocks got hit hard last month as a com...
# 2024-02-03  (Thanks to its lineup of incredibly popular ha...
# 2024-02-03  (Bullish investors are sure that there is a lo...
# 2024-02-03  (Investing in the stock market is one of the m...
# 2024-02-03  (Shares in Advanced Micro Devices (NASDAQ: AMD...
# ...                                                       ...
# 2023-12-19  (Here's a look at my six largest holdings head...
# 2023-12-19  (Among the underlying components of the Russel...
# 2023-12-19  (In addition to active ETFs, popular new ETFs ...
# 2023-12-19  (More than two years after the peak of meme co...
# 2023-12-18  (InvestorPlace - Stock Market News, Stock Advi...
#
#                                              Textrank_summary  \
# 2024-02-03  (China stocks got hit hard last month as a com...
# 2024-02-03  (Thanks to its lineup of incredibly popular ha...
# 2024-02-03  (But it stands out among the tens of thousands...
# 2024-02-03  (Investing in the stock market is one of the m...
# 2024-02-03  (The launch of OpenAI's ChatGPT in November 20...
# ...                                                       ...
# 2023-12-19  (Perhaps more importantly, the S&P 500 and the...
# 2023-12-19  (Among the underlying components of the Russel...
# 2023-12-19  (In addition to active ETFs, popular new ETFs ...
# 2023-12-19  (More than two years after the peak of meme co...
# 2023-12-18  (InvestorPlace - Stock Market News, Stock Advi...
#
#                                               Lexrank_summary
# 2024-02-03  (China stocks got hit hard last month as a com...
# 2024-02-03  (Thanks to its lineup of incredibly popular ha...
# 2024-02-03  (At a price of just over $43,000 as of Feb. 1,...
# 2024-02-03  (Exchange-traded funds (ETFs) can be fantastic...
# 2024-02-03  (Shares in Advanced Micro Devices (NASDAQ: AMD...
# ...                                                       ...
# 2023-12-19  (Here's a look at my six largest holdings head...
# 2023-12-19  (Among the underlying components of the Russel...
# 2023-12-19  (Of the funds launched in 2023, 76% were activ...
# 2023-12-19  (More than two years after the peak of meme co...
# 2023-12-18  (This increasing enthusiasm has significantly ...
#
# [644 rows x 4 columns]

# %%
df.iloc[0, 0]
# Out:
# (<Sentence: China stocks got hit hard last month as a combination of weak economic data, interventions by the Chinese government against selling stocks, and ongoing regulatory concerns pushed the sector down broadly.>,
#  <Sentence: JD data by YCharts China stocks continue to struggle Chinese stocks started off the month on the wrong foot as China reported GDP growth of just 5.2% for 2023.>,
#  <Sentence: While that would be a good pace for any country, it marked China's slowest yearly growth in 30 years, and its GDP growth slowed to just 4.1% in the fourth quarter.>,
#  <Sentence: Investors also seemed spooked that Beijing told some investors not to sell Chinese stock amid a rotation among some money managers from China to Japan.>,
#  <Sentence: That was the latest sign of weakness in China's real estate sector.>,
#  <Sentence: Those news items all pressured China stocks further, while JD, PDD, and Baidu faced their own challenges.>,
#  <Sentence: It has lost market share to PDD Holdings' Pinduoduo, which has been growing rapidly through its social commerce model, which offers discounted prices for group buyers.>,
#  <Sentence: The remarks echoed a similar call to action from Alibaba founder Jack Ma.>,
#  <Sentence: The success of Temu helped drive PDD's revenue up 94% in the third quarter, though that growth is likely to decelerate soon, since it's difficult for any retailer to double sales each quarter, especially a company that's approaching a run rate of $40 billion in revenue.>,
#  <Sentence: Finally, Baidu's stock fell in the middle of the month after an article came out linking its Ernie AI platform to military research, which could spark a response from the U.S. government, which has already tightened restrictions over what chips can be exported to China.>,
#  <Sentence: Apple just reported a sales decline in China, offering further evidence of the weak economy.>,
#  <Sentence: Baidu's AI chatbot also seems promising, but investors may want to tread cautiously in the sector, as the economic malaise in China seems likely to continue.>,
#  <Sentence: Stock Advisor provides investors with an easy-to-follow blueprint for success, including guidance on building a portfolio, regular updates from analysts, and two new stock picks each month.>)

# %%
df[summ_bots] = df[summ_bots].map(lambda cell: " ".join(str(sent) for sent in cell))
df
# Out:
#                                                   Lsa_summary  \
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Maybe its turnaround plans could get a boost w...
# 2024-02-03  Since its price cratered 65% in 2022, Bitcoin ...
# 2024-02-03  The S&P 500 recently reached a new all-time hi...
# 2024-02-03  Meanwhile, its free cash flow has plunged 47% ...
# ...                                                       ...
# 2023-12-19  Each of the major market indexes has gained mo...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  Of the funds launched in 2023, 76% were active...
# 2023-12-19  Shiba Inu is still up just 25% for the year am...
# 2023-12-18  This increasing enthusiasm has significantly i...
#
#                                                  Luhn_summary  \
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Thanks to its lineup of incredibly popular har...
# 2024-02-03  Bullish investors are sure that there is a lot...
# 2024-02-03  Investing in the stock market is one of the mo...
# 2024-02-03  Shares in Advanced Micro Devices (NASDAQ: AMD)...
# ...                                                       ...
# 2023-12-19  Here's a look at my six largest holdings headi...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  In addition to active ETFs, popular new ETFs i...
# 2023-12-19  More than two years after the peak of meme coi...
# 2023-12-18  InvestorPlace - Stock Market News, Stock Advic...
#
#                                              Textrank_summary  \
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Thanks to its lineup of incredibly popular har...
# 2024-02-03  But it stands out among the tens of thousands ...
# 2024-02-03  Investing in the stock market is one of the mo...
# 2024-02-03  The launch of OpenAI's ChatGPT in November 202...
# ...                                                       ...
# 2023-12-19  Perhaps more importantly, the S&P 500 and the ...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  In addition to active ETFs, popular new ETFs i...
# 2023-12-19  More than two years after the peak of meme coi...
# 2023-12-18  InvestorPlace - Stock Market News, Stock Advic...
#
#                                               Lexrank_summary
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Thanks to its lineup of incredibly popular har...
# 2024-02-03  At a price of just over $43,000 as of Feb. 1, ...
# 2024-02-03  Exchange-traded funds (ETFs) can be fantastic ...
# 2024-02-03  Shares in Advanced Micro Devices (NASDAQ: AMD)...
# ...                                                       ...
# 2023-12-19  Here's a look at my six largest holdings headi...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  Of the funds launched in 2023, 76% were active...
# 2023-12-19  More than two years after the peak of meme coi...
# 2023-12-18  This increasing enthusiasm has significantly i...
#
# [644 rows x 4 columns]

# %%
df.iloc[0, 0]
# Out:
# "China stocks got hit hard last month as a combination of weak economic data, interventions by the Chinese government against selling stocks, and ongoing regulatory concerns pushed the sector down broadly. JD data by YCharts China stocks continue to struggle Chinese stocks started off the month on the wrong foot as China reported GDP growth of just 5.2% for 2023. While that would be a good pace for any country, it marked China's slowest yearly growth in 30 years, and its GDP growth slowed to just 4.1% in the fourth quarter. Investors also seemed spooked that Beijing told some investors not to sell Chinese stock amid a rotation among some money managers from China to Japan. That was the latest sign of weakness in China's real estate sector. Those news items all pressured China stocks further, while JD, PDD, and Baidu faced their own challenges. It has lost market share to PDD Holdings' Pinduoduo, which has been growing rapidly through its social commerce model, which offers discounted prices for group buyers. The remarks echoed a similar call to action from Alibaba founder Jack Ma. The success of Temu helped drive PDD's revenue up 94% in the third quarter, though that growth is likely to decelerate soon, since it's difficult for any retailer to double sales each quarter, especially a company that's approaching a run rate of $40 billion in revenue. Finally, Baidu's stock fell in the middle of the month after an article came out linking its Ernie AI platform to military research, which could spark a response from the U.S. government, which has already tightened restrictions over what chips can be exported to China. Apple just reported a sales decline in China, offering further evidence of the weak economy. Baidu's AI chatbot also seems promising, but investors may want to tread cautiously in the sector, as the economic malaise in China seems likely to continue. Stock Advisor provides investors with an easy-to-follow blueprint for success, including guidance on building a portfolio, regular updates from analysts, and two new stock picks each month."

# %% [markdown]
# ## Export

# %%
# Make output directory
out_dir = f"../{tick.lower()}_data"
os.makedirs(f"../{tick.lower()}_data", exist_ok=True)

# %%
# Export to csv
df.to_csv(os.path.join(out_dir, "summaries.csv"))

# %%
df
# Out:
#                                                   Lsa_summary  \
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Maybe its turnaround plans could get a boost w...
# 2024-02-03  Since its price cratered 65% in 2022, Bitcoin ...
# 2024-02-03  The S&P 500 recently reached a new all-time hi...
# 2024-02-03  Meanwhile, its free cash flow has plunged 47% ...
# ...                                                       ...
# 2023-12-19  Each of the major market indexes has gained mo...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  Of the funds launched in 2023, 76% were active...
# 2023-12-19  Shiba Inu is still up just 25% for the year am...
# 2023-12-18  This increasing enthusiasm has significantly i...
#
#                                                  Luhn_summary  \
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Thanks to its lineup of incredibly popular har...
# 2024-02-03  Bullish investors are sure that there is a lot...
# 2024-02-03  Investing in the stock market is one of the mo...
# 2024-02-03  Shares in Advanced Micro Devices (NASDAQ: AMD)...
# ...                                                       ...
# 2023-12-19  Here's a look at my six largest holdings headi...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  In addition to active ETFs, popular new ETFs i...
# 2023-12-19  More than two years after the peak of meme coi...
# 2023-12-18  InvestorPlace - Stock Market News, Stock Advic...
#
#                                              Textrank_summary  \
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Thanks to its lineup of incredibly popular har...
# 2024-02-03  But it stands out among the tens of thousands ...
# 2024-02-03  Investing in the stock market is one of the mo...
# 2024-02-03  The launch of OpenAI's ChatGPT in November 202...
# ...                                                       ...
# 2023-12-19  Perhaps more importantly, the S&P 500 and the ...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  In addition to active ETFs, popular new ETFs i...
# 2023-12-19  More than two years after the peak of meme coi...
# 2023-12-18  InvestorPlace - Stock Market News, Stock Advic...
#
#                                               Lexrank_summary
# 2024-02-03  China stocks got hit hard last month as a comb...
# 2024-02-03  Thanks to its lineup of incredibly popular har...
# 2024-02-03  At a price of just over $43,000 as of Feb. 1, ...
# 2024-02-03  Exchange-traded funds (ETFs) can be fantastic ...
# 2024-02-03  Shares in Advanced Micro Devices (NASDAQ: AMD)...
# ...                                                       ...
# 2023-12-19  Here's a look at my six largest holdings headi...
# 2023-12-19  Among the underlying components of the Russell...
# 2023-12-19  Of the funds launched in 2023, 76% were active...
# 2023-12-19  More than two years after the peak of meme coi...
# 2023-12-18  This increasing enthusiasm has significantly i...
#
# [644 rows x 4 columns]
