# %% [markdown]
# # XGBoost Recursive Algorithm

# %% [markdown]
# ## Necessary Configuration

# %%
# XGBoost imports
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from skforecast.direct import ForecasterDirect
import matplotlib.pyplot as plt
import optuna
import plotly.io as pio
pio.renderers.default = 'notebook'  # or 'colab', 'iframe', 'vscode' depending on environment

from skforecast.plot import set_dark_theme
from datetime import datetime, timedelta
from skforecast.model_selection import backtesting_forecaster
from skforecast.model_selection import TimeSeriesFold
import sys

# %%
# Path imports
import os
from pathlib import Path
from IPython import get_ipython

# Set notebook directory as cwd
try:
    notebook_path = get_ipython().run_line_magic("pwd", "")  # Gets notebook's folder
    os.chdir(notebook_path)
    print("CWD set to notebook folder:", os.getcwd())
except Exception as e:
    print("Could not set CWD:", e)
# Out:
# CWD set to notebook folder: C:\Users\karth\Documents\StockBot\algo_training\xg_boost

# %% [markdown]
# ## Obtain and configure dataset

# %%
# Ticker name
tick = "NVDA"

# Whether or not to use truncated data
truncated = False
# Load time-indexed stock price dataset
if truncated:
    total = pd.read_csv(f"../single_stock/{tick.lower()}_data/truncated.csv")
else:
    total = pd.read_csv(f"../single_stock/{tick.lower()}_data/full.csv")

total.set_index("date", inplace=True)
total.index = pd.to_datetime(total.index, errors="raise")

total
# Out:
#                  open      close       high        low        volume  \
# date
# 2011-03-03   0.486664   0.478412   0.489415   0.463970  1.593704e+09
# 2011-03-04   0.478870   0.475890   0.483684   0.470618  9.597600e+08
# 2011-03-07   0.479329   0.469243   0.480933   0.457322  1.019140e+09
# 2011-03-08   0.474286   0.448153   0.476807   0.438296  1.947184e+09
# 2011-03-09   0.446778   0.438754   0.451133   0.434857  1.318976e+09
# ...               ...        ...        ...        ...           ...
# 2023-12-11  47.469876  46.606258  47.509856  45.809616  5.097280e+08
# 2023-12-12  46.025520  47.635803  47.644798  46.025520  3.723870e+08
# 2023-12-13  47.607821  48.066616  48.572392  47.586830  4.477920e+08
# 2023-12-14  48.368474  48.328491  48.648349  47.400906  3.912320e+08
# 2023-12-15  48.172562  48.868252  49.382023  48.098594  4.799480e+08
#
#             dividends  stock splits       lsa      luhn  textrank   lexrank
# date
# 2011-03-03        0.0           0.0       NaN       NaN       NaN       NaN
# 2011-03-04        0.0           0.0       NaN       NaN       NaN       NaN
# 2011-03-07        0.0           0.0       NaN       NaN       NaN       NaN
# 2011-03-08        0.0           0.0       NaN       NaN       NaN       NaN
# 2011-03-09        0.0           0.0       NaN       NaN       NaN       NaN
# ...               ...           ...       ...       ...       ...       ...
# 2023-12-11        0.0           0.0 -5.583224 -5.583224 -5.583224 -5.583224
# 2023-12-12        0.0           0.0 -3.547586 -3.547586 -3.547586 -3.547586
# 2023-12-13        0.0           0.0 -0.665740 -0.665740 -0.665740 -0.665740
# 2023-12-14        0.0           0.0  3.056196  3.056196  3.056196  3.056196
# 2023-12-15        0.0           0.0  2.649434  2.649434  2.649434  2.649434
#
# [3220 rows x 11 columns]

# %% [markdown]
# ## Train-test Split

# %%
# Sort in descending order
total.sort_index(ascending=False, inplace=True)

# Train-test split
train, test = None, None

if truncated:
    train, test = train_test_split(
        total, 
        train_size=0.85, 
        shuffle=False, 
        test_size=0.15
    )
else:
    # Get length of sentiment available days portion
    first_idx = total.loc[:, 'lsa'].first_valid_index()
    last_idx = total.loc[:, 'lsa'].last_valid_index()
    diff = last_idx - first_idx

    # Splice it by .85 to get train and test
    delta = timedelta((diff*.85).days)
    
    # if total.index.get_loc(first_idx) + 1 > total.shape[0] - total.index.get_loc(last_idx):
    mid_idx = first_idx + delta
    train = total.loc[:mid_idx]
    test = total.loc[mid_idx:]
    # else:
    #     mid_idx = last_idx - delta
    #     test = total.loc[:mid_idx]
    #     train = total.loc[mid_idx:]

# %%
print(mid_idx)
# Out:
# 2021-12-22 00:00:00

# %% [markdown]
# ## XGBoost and Indicator Hyperparameter Optimization with Optuna

# %%
# Importing a file
import sys
sys.path.insert(0, "../../")
from indicator import add_indicators

# Automating the hyperparameters
def objective(trial):
    #XGBoost Hyperparameters
    lags = trial.suggest_int("lags", 3, 20)
    n_estimators = trial.suggest_int("n_estimators", 50, 300)
    max_depth = trial.suggest_int("max_depth", 2, 6)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3)
    subsample = trial.suggest_float("subsample", 0.5, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1.0)
    gamma = trial.suggest_float("gamma", 0, 7)
    n_steps = trial.suggest_int("n_steps", 1, 30)

    # Technical indicators (tunable)
    sma = {
        trial.suggest_int("smap1", 3, 11),
        trial.suggest_int("smap2", 11, 21),
        trial.suggest_int("smap3", 21, 51),
        trial.suggest_int("smap4", 51, 201),
    }
    ema = {
        trial.suggest_int("emap1", 5, 13),
        trial.suggest_int("emap2", 13, 27),
        trial.suggest_int("emap3", 27, 51),
        trial.suggest_int("emap4", 51, 101),
    }
    macd_fast = trial.suggest_int("macd_fast",   10, 15)
    macd_slow = trial.suggest_int("macd_slow", 20, 30)
    macd_signal = trial.suggest_int("macd_signal", 7, 12)
    rsi_window = trial.suggest_int("rsi_window", 10, 20)
    srsi_window = trial.suggest_int("srsi_window", 10, 20)
    srsi_k = trial.suggest_int("srsi_k", 2, 5)
    srsi_d = trial.suggest_int("srsi_d", 2, 5)
    roc_window = trial.suggest_int("roc_window", 10, 20)
    mom_window = trial.suggest_int("mom_window", 5, 15)
    cmf_window = trial.suggest_int("cmf_window", 10, 30)
    mfi_window = trial.suggest_int("mfi_window", 10, 20)
    bollinger_window = trial.suggest_int("bollinger_window", 15, 30)
    bollinger_num_std = trial.suggest_int("bollinger_num_std", 1, 3)
    inc_obv = trial.suggest_categorical("inc_obv", [True, False])
    atr_window = trial.suggest_int("atr_window", 10, 20)
    donchian_window = trial.suggest_int("donchian_window", 15, 30)
    trix_window = trial.suggest_int("trix_window", 10, 20)
    inc_fib = trial.suggest_categorical("inc_fib", [True, False])
    pc_window = trial.suggest_int("pc_window", 15, 30)
    inc_fractals = trial.suggest_categorical("inc_fractals", [True, False])

    # This will allow indicators to be tuned, minimizing information loss when extracting patterns
    train_loc = add_indicators(
        train,
        smap=sma,
        emap=ema,
        macd_fast=macd_fast,
        macd_slow=macd_slow,
        macd_signal=macd_signal,
        rsi_window=rsi_window,
        srsi_window=srsi_window,
        srsi_k=srsi_k,
        srsi_d=srsi_d,
        roc_window=roc_window,
        mom_window=mom_window,
        cmf_window=cmf_window,
        mfi_window=mfi_window,
        bollinger_window=bollinger_window,
        bollinger_num_std=bollinger_num_std,
        inc_obv=inc_obv,
        atr_window=atr_window,
        donchian_window=donchian_window,
        trix_window=trix_window,
        inc_fib=inc_fib,
        pc_window=pc_window,
        inc_fractals=inc_fractals)

    test_loc = add_indicators(
        test,
        smap=sma,
        emap=ema,
        macd_fast=macd_fast,
        macd_slow=macd_slow,
        macd_signal=macd_signal,
        rsi_window=rsi_window,
        srsi_window=srsi_window,
        srsi_k=srsi_k,
        srsi_d=srsi_d,
        roc_window=roc_window,
        mom_window=mom_window,
        cmf_window=cmf_window,
        mfi_window=mfi_window,
        bollinger_window=bollinger_window,
        bollinger_num_std=bollinger_num_std,
        inc_obv=inc_obv,
        atr_window=atr_window,
        donchian_window=donchian_window,
        trix_window=trix_window,
        inc_fib=inc_fib,
        pc_window=pc_window,
        inc_fractals=inc_fractals)

    # Fill index
    train_loc.index = pd.to_datetime(train_loc.index, errors="raise")
    test_loc.index = pd.to_datetime(test_loc.index, errors="raise")

    # Make sure interval is set
    train_loc = train_loc.asfreq("D")
    test_loc = test_loc.asfreq("D")
    
    # Sort in ascending order
    train_loc.sort_index(ascending=True, inplace=True)
    test_loc.sort_index(ascending=True, inplace=True)

    # Fill missing
    train_loc.loc[:, "open":"lsa"] = train_loc.loc[:, "open":"lsa"].ffill()
    test_loc.loc[:, "open":"lsa"] = train_loc.loc[:, "open":"lsa"].ffill()

    # XGB Model
    model = XGBRegressor(
        tree_method="hist",
        predictor="predictor",
        device="cuda",
        verbosity=1, # Shows logs, to know if using cuda
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma=gamma,
        random_state=42
    )

    # Adds forecasting
    forecaster = ForecasterDirect(
        regressor=model,
        lags=lags,
        steps=n_steps
    )

    # Train model
    exog_train = train_loc.drop(columns="close")
    exog_test = test_loc.drop(columns="close").drop(index=test_loc.index[0])

    y_train = train_loc["close"]
    y_test = test_loc["close"]


    # assert len(exog_test) == len(y_test)
    # exog_test = exog_test.reindex(y_test.index)

    # train_loc.drop(index=train_loc.index[-1], inplace=True)
    # test_loc.drop(index=test_loc.index[-1], inplace=True)

    # forecaster.fit(
    #     y=y_train,
    #     exog=exog_train
    # )
    
    # Test model
    # try:
    cv = TimeSeriesFold(
        initial_train_size      = len(train),
        fixed_train_size        = True,
        steps                   = n_steps,
        refit                   = True,
        allow_incomplete_fold   = False
    )

    y_full = pd.concat([y_train, y_test]).dropna()
    exog_full = pd.concat([exog_train, exog_test])
    
    if not y_full.index.is_unique:
        y_full = y_full[~y_full.index.duplicated(keep='first')]
    y_full = y_full.asfreq('D', fill_value=np.nan).ffill()
    
    if not exog_full.index.is_unique:
        exog_full = exog_full[~exog_full.index.duplicated(keep='first')]
    exog_full = exog_full.asfreq('D', fill_value=np.nan)

    exog_full = exog_full.reindex(y_full.index)
    assert len(exog_full) == len(y_full), f"""MY ASSERTION FAIED😭😭😭😭😭😭😭😭😭😭!!!!!!
exog: {len(exog_full)}
y: {len(y_full)}
    """
    
    results, predictions = backtesting_forecaster(
        forecaster          = forecaster,
        y                   = y_full,  # full series
        cv                  = cv,
        exog                = exog_full,
        metric              = 'root_mean_squared_error',
        show_progress       = False
    )

    # results_df will have one row per fold, with a column named ‘root_mean_squared_scaled_error’
    return results['root_mean_squared_error'].iloc[0]
    # except Exception:
    #     print("TERRIBLE, HORRIBLE")
    #     return sys.maxint

# %% [markdown]
# ## Execution of model

# %%
import warnings
warnings.simplefilter("ignore")

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50, show_progress_bar = True)

# Print the best hyperparameters
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2025-07-31 23:27:20,090] A new study created in memory with name: no-name-a8d142bd-7ff6-4f4e-82bc-4f52aa0365e7
#   0%|          | 0/600 [00:00<?, ?it/s]
# [I 2025-07-31 23:29:04,702] Trial 0 finished with value: 5.162846344478583 and parameters: {'lags': 19, 'n_estimators': 242, 'max_depth': 5, 'learning_rate': 0.019653974106645197, 'subsample': 0.885406499558496, 'colsample_bytree': 0.6635839703651267, 'gamma': 1.4150408978861553, 'n_steps': 21, 'smap1': 9, 'smap2': 11, 'smap3': 30, 'smap4': 121, 'emap1': 12, 'emap2': 20, 'emap3': 42, 'emap4': 88, 'macd_fast': 10, 'macd_slow': 30, 'macd_signal': 7, 'rsi_window': 18, 'srsi_window': 20, 'srsi_k': 4, 'srsi_d': 2, 'roc_window': 15, 'mom_window': 10, 'cmf_window': 12, 'mfi_window': 20, 'bollinger_window': 25, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 10, 'donchian_window': 24, 'trix_window': 17, 'inc_fib': False, 'pc_window': 17, 'inc_fractals': True}. Best is trial 0 with value: 5.162846344478583.
# [I 2025-07-31 23:29:40,857] Trial 1 finished with value: 3.6960380524132628 and parameters: {'lags': 18, 'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.08443515952562924, 'subsample': 0.5049910911592433, 'colsample_bytree': 0.6811742126006031, 'gamma': 1.1127970597634569, 'n_steps': 12, 'smap1': 4, 'smap2': 15, 'smap3': 33, 'smap4': 51, 'emap1': 11, 'emap2': 19, 'emap3': 47, 'emap4': 81, 'macd_fast': 12, 'macd_slow': 28, 'macd_signal': 8, 'rsi_window': 17, 'srsi_window': 14, 'srsi_k': 4, 'srsi_d': 4, 'roc_window': 18, 'mom_window': 11, 'cmf_window': 21, 'mfi_window': 15, 'bollinger_window': 25, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 27, 'trix_window': 16, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': False}. Best is trial 1 with value: 3.6960380524132628.
# [I 2025-07-31 23:30:50,308] Trial 2 finished with value: 4.257156261348612 and parameters: {'lags': 7, 'n_estimators': 291, 'max_depth': 6, 'learning_rate': 0.1609620615370436, 'subsample': 0.6566354570291459, 'colsample_bytree': 0.6660784594941261, 'gamma': 5.646482275074257, 'n_steps': 14, 'smap1': 7, 'smap2': 17, 'smap3': 25, 'smap4': 75, 'emap1': 7, 'emap2': 27, 'emap3': 28, 'emap4': 88, 'macd_fast': 12, 'macd_slow': 23, 'macd_signal': 9, 'rsi_window': 12, 'srsi_window': 10, 'srsi_k': 2, 'srsi_d': 4, 'roc_window': 11, 'mom_window': 5, 'cmf_window': 28, 'mfi_window': 18, 'bollinger_window': 27, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 17, 'donchian_window': 22, 'trix_window': 20, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': True}. Best is trial 1 with value: 3.6960380524132628.
# [I 2025-07-31 23:31:42,040] Trial 3 finished with value: 3.023979495576463 and parameters: {'lags': 8, 'n_estimators': 183, 'max_depth': 5, 'learning_rate': 0.12426129740958268, 'subsample': 0.6253060394548211, 'colsample_bytree': 0.6207886791949464, 'gamma': 2.371931278788198, 'n_steps': 8, 'smap1': 3, 'smap2': 20, 'smap3': 31, 'smap4': 192, 'emap1': 5, 'emap2': 25, 'emap3': 34, 'emap4': 85, 'macd_fast': 13, 'macd_slow': 25, 'macd_signal': 10, 'rsi_window': 19, 'srsi_window': 17, 'srsi_k': 3, 'srsi_d': 2, 'roc_window': 14, 'mom_window': 14, 'cmf_window': 10, 'mfi_window': 20, 'bollinger_window': 26, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 16, 'donchian_window': 17, 'trix_window': 18, 'inc_fib': True, 'pc_window': 17, 'inc_fractals': True}. Best is trial 3 with value: 3.023979495576463.
# [I 2025-07-31 23:32:42,013] Trial 4 finished with value: 3.958892601032419 and parameters: {'lags': 12, 'n_estimators': 255, 'max_depth': 4, 'learning_rate': 0.21935514849865903, 'subsample': 0.9093984248395662, 'colsample_bytree': 0.8518813684681722, 'gamma': 1.227016924767048, 'n_steps': 15, 'smap1': 11, 'smap2': 13, 'smap3': 47, 'smap4': 125, 'emap1': 7, 'emap2': 14, 'emap3': 35, 'emap4': 71, 'macd_fast': 10, 'macd_slow': 28, 'macd_signal': 9, 'rsi_window': 11, 'srsi_window': 11, 'srsi_k': 4, 'srsi_d': 3, 'roc_window': 10, 'mom_window': 8, 'cmf_window': 21, 'mfi_window': 15, 'bollinger_window': 23, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 20, 'donchian_window': 25, 'trix_window': 15, 'inc_fib': False, 'pc_window': 29, 'inc_fractals': True}. Best is trial 3 with value: 3.023979495576463.
# [I 2025-07-31 23:33:15,375] Trial 5 finished with value: 4.015690214904734 and parameters: {'lags': 12, 'n_estimators': 124, 'max_depth': 2, 'learning_rate': 0.06858857495311672, 'subsample': 0.6429490085870466, 'colsample_bytree': 0.6356599570696996, 'gamma': 4.615972796646877, 'n_steps': 12, 'smap1': 5, 'smap2': 19, 'smap3': 22, 'smap4': 176, 'emap1': 10, 'emap2': 17, 'emap3': 35, 'emap4': 73, 'macd_fast': 13, 'macd_slow': 23, 'macd_signal': 8, 'rsi_window': 13, 'srsi_window': 12, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 12, 'mom_window': 8, 'cmf_window': 26, 'mfi_window': 10, 'bollinger_window': 19, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 12, 'donchian_window': 24, 'trix_window': 19, 'inc_fib': False, 'pc_window': 24, 'inc_fractals': True}. Best is trial 3 with value: 3.023979495576463.
# [I 2025-07-31 23:34:07,774] Trial 6 finished with value: 3.360905212578502 and parameters: {'lags': 8, 'n_estimators': 203, 'max_depth': 6, 'learning_rate': 0.2387331659059748, 'subsample': 0.9681400704194363, 'colsample_bytree': 0.8434547412512465, 'gamma': 2.319091969553731, 'n_steps': 9, 'smap1': 7, 'smap2': 21, 'smap3': 44, 'smap4': 82, 'emap1': 11, 'emap2': 23, 'emap3': 40, 'emap4': 76, 'macd_fast': 11, 'macd_slow': 25, 'macd_signal': 9, 'rsi_window': 19, 'srsi_window': 17, 'srsi_k': 2, 'srsi_d': 2, 'roc_window': 19, 'mom_window': 5, 'cmf_window': 21, 'mfi_window': 16, 'bollinger_window': 27, 'bollinger_num_std': 3, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 16, 'trix_window': 16, 'inc_fib': False, 'pc_window': 26, 'inc_fractals': False}. Best is trial 3 with value: 3.023979495576463.
# [I 2025-07-31 23:35:05,998] Trial 7 finished with value: 6.055542454064338 and parameters: {'lags': 8, 'n_estimators': 292, 'max_depth': 2, 'learning_rate': 0.12796203856124436, 'subsample': 0.9791350419336098, 'colsample_bytree': 0.5461708203047386, 'gamma': 2.021583113765149, 'n_steps': 26, 'smap1': 5, 'smap2': 21, 'smap3': 28, 'smap4': 181, 'emap1': 10, 'emap2': 23, 'emap3': 40, 'emap4': 58, 'macd_fast': 10, 'macd_slow': 27, 'macd_signal': 8, 'rsi_window': 17, 'srsi_window': 19, 'srsi_k': 2, 'srsi_d': 4, 'roc_window': 13, 'mom_window': 10, 'cmf_window': 13, 'mfi_window': 16, 'bollinger_window': 15, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 19, 'donchian_window': 23, 'trix_window': 12, 'inc_fib': True, 'pc_window': 17, 'inc_fractals': True}. Best is trial 3 with value: 3.023979495576463.
# [I 2025-07-31 23:35:40,238] Trial 8 finished with value: 5.497051917046384 and parameters: {'lags': 14, 'n_estimators': 134, 'max_depth': 5, 'learning_rate': 0.19669610392346618, 'subsample': 0.688772323269693, 'colsample_bytree': 0.7162353837903188, 'gamma': 1.2341419347777927, 'n_steps': 24, 'smap1': 6, 'smap2': 18, 'smap3': 40, 'smap4': 131, 'emap1': 12, 'emap2': 18, 'emap3': 47, 'emap4': 57, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 9, 'rsi_window': 20, 'srsi_window': 10, 'srsi_k': 3, 'srsi_d': 4, 'roc_window': 12, 'mom_window': 11, 'cmf_window': 21, 'mfi_window': 20, 'bollinger_window': 20, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 18, 'donchian_window': 16, 'trix_window': 12, 'inc_fib': False, 'pc_window': 29, 'inc_fractals': False}. Best is trial 3 with value: 3.023979495576463.
# [I 2025-07-31 23:36:20,063] Trial 9 finished with value: 2.6521116501826563 and parameters: {'lags': 4, 'n_estimators': 169, 'max_depth': 4, 'learning_rate': 0.16368181235845985, 'subsample': 0.9142096255892058, 'colsample_bytree': 0.5165296459526747, 'gamma': 5.86528149806494, 'n_steps': 5, 'smap1': 11, 'smap2': 17, 'smap3': 48, 'smap4': 158, 'emap1': 9, 'emap2': 26, 'emap3': 43, 'emap4': 54, 'macd_fast': 13, 'macd_slow': 22, 'macd_signal': 9, 'rsi_window': 16, 'srsi_window': 18, 'srsi_k': 2, 'srsi_d': 5, 'roc_window': 13, 'mom_window': 5, 'cmf_window': 20, 'mfi_window': 18, 'bollinger_window': 27, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 14, 'donchian_window': 16, 'trix_window': 15, 'inc_fib': True, 'pc_window': 21, 'inc_fractals': False}. Best is trial 9 with value: 2.6521116501826563.
# [I 2025-07-31 23:36:47,440] Trial 10 finished with value: 1.9195933501724307 and parameters: {'lags': 3, 'n_estimators': 61, 'max_depth': 3, 'learning_rate': 0.29765579194295244, 'subsample': 0.7976637279656763, 'colsample_bytree': 0.5080185332357591, 'gamma': 6.474173472755808, 'n_steps': 1, 'smap1': 11, 'smap2': 15, 'smap3': 51, 'smap4': 157, 'emap1': 8, 'emap2': 27, 'emap3': 51, 'emap4': 100, 'macd_fast': 15, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 15, 'srsi_window': 16, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 14, 'cmf_window': 16, 'mfi_window': 12, 'bollinger_window': 29, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 14, 'donchian_window': 19, 'trix_window': 10, 'inc_fib': True, 'pc_window': 21, 'inc_fractals': False}. Best is trial 10 with value: 1.9195933501724307.
# [I 2025-07-31 23:37:06,957] Trial 11 finished with value: 2.303273945733213 and parameters: {'lags': 3, 'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.2885888519495793, 'subsample': 0.810572811258986, 'colsample_bytree': 0.5093402227206164, 'gamma': 6.529885266813803, 'n_steps': 2, 'smap1': 11, 'smap2': 15, 'smap3': 51, 'smap4': 160, 'emap1': 8, 'emap2': 27, 'emap3': 51, 'emap4': 101, 'macd_fast': 15, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 15, 'srsi_window': 16, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 15, 'cmf_window': 16, 'mfi_window': 11, 'bollinger_window': 30, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 14, 'donchian_window': 19, 'trix_window': 10, 'inc_fib': True, 'pc_window': 21, 'inc_fractals': False}. Best is trial 10 with value: 1.9195933501724307.
# [I 2025-07-31 23:37:33,994] Trial 12 finished with value: 2.0201157634777407 and parameters: {'lags': 3, 'n_estimators': 58, 'max_depth': 3, 'learning_rate': 0.27673730406267616, 'subsample': 0.7921902703155865, 'colsample_bytree': 0.9872872743389439, 'gamma': 6.95498284309504, 'n_steps': 1, 'smap1': 9, 'smap2': 15, 'smap3': 50, 'smap4': 150, 'emap1': 8, 'emap2': 23, 'emap3': 49, 'emap4': 101, 'macd_fast': 15, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 14, 'srsi_window': 15, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 17, 'mom_window': 15, 'cmf_window': 17, 'mfi_window': 11, 'bollinger_window': 30, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 10, 'inc_fib': True, 'pc_window': 21, 'inc_fractals': False}. Best is trial 10 with value: 1.9195933501724307.
# [I 2025-07-31 23:38:06,681] Trial 13 finished with value: 1.7965905833074474 and parameters: {'lags': 5, 'n_estimators': 88, 'max_depth': 3, 'learning_rate': 0.29359918096878884, 'subsample': 0.7840865392826863, 'colsample_bytree': 0.9910737989580667, 'gamma': 4.2215460614507325, 'n_steps': 1, 'smap1': 9, 'smap2': 13, 'smap3': 39, 'smap4': 145, 'emap1': 5, 'emap2': 23, 'emap3': 51, 'emap4': 100, 'macd_fast': 14, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 14, 'srsi_window': 14, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 17, 'mom_window': 13, 'cmf_window': 16, 'mfi_window': 12, 'bollinger_window': 30, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 10, 'inc_fib': True, 'pc_window': 20, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:38:31,389] Trial 14 finished with value: 2.522381615451489 and parameters: {'lags': 6, 'n_estimators': 103, 'max_depth': 3, 'learning_rate': 0.2959096344621868, 'subsample': 0.7517039727645443, 'colsample_bytree': 0.992675573334516, 'gamma': 3.828050551791405, 'n_steps': 5, 'smap1': 9, 'smap2': 13, 'smap3': 39, 'smap4': 109, 'emap1': 5, 'emap2': 21, 'emap3': 51, 'emap4': 94, 'macd_fast': 14, 'macd_slow': 22, 'macd_signal': 11, 'rsi_window': 10, 'srsi_window': 13, 'srsi_k': 5, 'srsi_d': 3, 'roc_window': 19, 'mom_window': 13, 'cmf_window': 16, 'mfi_window': 13, 'bollinger_window': 30, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 13, 'donchian_window': 20, 'trix_window': 12, 'inc_fib': True, 'pc_window': 24, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:38:52,667] Trial 15 finished with value: 6.879530806327225 and parameters: {'lags': 5, 'n_estimators': 91, 'max_depth': 3, 'learning_rate': 0.24235853740954094, 'subsample': 0.8342717709748629, 'colsample_bytree': 0.8087518794133813, 'gamma': 4.619266061956643, 'n_steps': 30, 'smap1': 10, 'smap2': 13, 'smap3': 43, 'smap4': 144, 'emap1': 6, 'emap2': 24, 'emap3': 46, 'emap4': 95, 'macd_fast': 14, 'macd_slow': 20, 'macd_signal': 11, 'rsi_window': 14, 'srsi_window': 14, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 13, 'cmf_window': 18, 'mfi_window': 13, 'bollinger_window': 29, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 16, 'donchian_window': 30, 'trix_window': 13, 'inc_fib': True, 'pc_window': 19, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:39:38,389] Trial 16 finished with value: 4.772324029533982 and parameters: {'lags': 10, 'n_estimators': 133, 'max_depth': 4, 'learning_rate': 0.2603605729877573, 'subsample': 0.7304730391235355, 'colsample_bytree': 0.9408882480432694, 'gamma': 0.03978643731303677, 'n_steps': 19, 'smap1': 8, 'smap2': 11, 'smap3': 35, 'smap4': 101, 'emap1': 6, 'emap2': 21, 'emap3': 44, 'emap4': 65, 'macd_fast': 14, 'macd_slow': 24, 'macd_signal': 11, 'rsi_window': 15, 'srsi_window': 15, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 20, 'mom_window': 13, 'cmf_window': 24, 'mfi_window': 13, 'bollinger_window': 23, 'bollinger_num_std': 3, 'inc_obv': True, 'atr_window': 16, 'donchian_window': 18, 'trix_window': 10, 'inc_fib': True, 'pc_window': 19, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:39:58,037] Trial 17 finished with value: 2.634639886097047 and parameters: {'lags': 16, 'n_estimators': 72, 'max_depth': 2, 'learning_rate': 0.19955106921552457, 'subsample': 0.5517701063013603, 'colsample_bytree': 0.7709300081125694, 'gamma': 3.486134214527296, 'n_steps': 5, 'smap1': 10, 'smap2': 14, 'smap3': 39, 'smap4': 175, 'emap1': 13, 'emap2': 25, 'emap3': 27, 'emap4': 94, 'macd_fast': 14, 'macd_slow': 22, 'macd_signal': 12, 'rsi_window': 13, 'srsi_window': 13, 'srsi_k': 5, 'srsi_d': 3, 'roc_window': 17, 'mom_window': 12, 'cmf_window': 14, 'mfi_window': 12, 'bollinger_window': 28, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 13, 'donchian_window': 21, 'trix_window': 13, 'inc_fib': True, 'pc_window': 23, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:40:33,077] Trial 18 finished with value: 1.8476781593183702 and parameters: {'lags': 5, 'n_estimators': 102, 'max_depth': 3, 'learning_rate': 0.29788806628433495, 'subsample': 0.8596668166921139, 'colsample_bytree': 0.9142591768124164, 'gamma': 5.087153361288848, 'n_steps': 1, 'smap1': 10, 'smap2': 12, 'smap3': 44, 'smap4': 140, 'emap1': 8, 'emap2': 15, 'emap3': 49, 'emap4': 94, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 11, 'rsi_window': 16, 'srsi_window': 16, 'srsi_k': 3, 'srsi_d': 4, 'roc_window': 15, 'mom_window': 14, 'cmf_window': 14, 'mfi_window': 10, 'bollinger_window': 21, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 18, 'trix_window': 11, 'inc_fib': True, 'pc_window': 26, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:41:03,064] Trial 19 finished with value: 3.330607235122642 and parameters: {'lags': 10, 'n_estimators': 108, 'max_depth': 4, 'learning_rate': 0.2554838174123064, 'subsample': 0.8605929104190009, 'colsample_bytree': 0.9277687434365954, 'gamma': 4.887084150625536, 'n_steps': 8, 'smap1': 8, 'smap2': 12, 'smap3': 44, 'smap4': 137, 'emap1': 6, 'emap2': 13, 'emap3': 48, 'emap4': 82, 'macd_fast': 14, 'macd_slow': 21, 'macd_signal': 10, 'rsi_window': 17, 'srsi_window': 17, 'srsi_k': 3, 'srsi_d': 4, 'roc_window': 15, 'mom_window': 12, 'cmf_window': 10, 'mfi_window': 10, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 15, 'trix_window': 11, 'inc_fib': True, 'pc_window': 27, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:41:37,517] Trial 20 finished with value: 2.623368371467294 and parameters: {'lags': 6, 'n_estimators': 149, 'max_depth': 2, 'learning_rate': 0.20499010473315943, 'subsample': 0.7667799376256884, 'colsample_bytree': 0.9037434744934879, 'gamma': 3.6068457753833885, 'n_steps': 4, 'smap1': 8, 'smap2': 12, 'smap3': 36, 'smap4': 108, 'emap1': 7, 'emap2': 15, 'emap3': 45, 'emap4': 92, 'macd_fast': 15, 'macd_slow': 26, 'macd_signal': 11, 'rsi_window': 16, 'srsi_window': 14, 'srsi_k': 3, 'srsi_d': 4, 'roc_window': 18, 'mom_window': 8, 'cmf_window': 14, 'mfi_window': 11, 'bollinger_window': 17, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 17, 'donchian_window': 18, 'trix_window': 14, 'inc_fib': True, 'pc_window': 27, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:42:08,755] Trial 21 finished with value: 1.9132926531323355 and parameters: {'lags': 5, 'n_estimators': 82, 'max_depth': 3, 'learning_rate': 0.2942821686584107, 'subsample': 0.7095053405426904, 'colsample_bytree': 0.8852120692495254, 'gamma': 5.66769152923651, 'n_steps': 1, 'smap1': 11, 'smap2': 14, 'smap3': 46, 'smap4': 162, 'emap1': 9, 'emap2': 16, 'emap3': 50, 'emap4': 98, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 14, 'srsi_window': 16, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 15, 'mom_window': 14, 'cmf_window': 18, 'mfi_window': 12, 'bollinger_window': 22, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 19, 'trix_window': 11, 'inc_fib': True, 'pc_window': 19, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:42:36,362] Trial 22 finished with value: 2.4440637306013477 and parameters: {'lags': 6, 'n_estimators': 106, 'max_depth': 3, 'learning_rate': 0.26087456883097954, 'subsample': 0.6867194659482233, 'colsample_bytree': 0.886888412722143, 'gamma': 5.410877266527216, 'n_steps': 3, 'smap1': 10, 'smap2': 14, 'smap3': 42, 'smap4': 166, 'emap1': 9, 'emap2': 16, 'emap3': 49, 'emap4': 97, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 13, 'srsi_window': 16, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 14, 'mom_window': 14, 'cmf_window': 19, 'mfi_window': 14, 'bollinger_window': 22, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 21, 'trix_window': 11, 'inc_fib': True, 'pc_window': 19, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:43:02,157] Trial 23 finished with value: 2.8735441705064435 and parameters: {'lags': 10, 'n_estimators': 90, 'max_depth': 3, 'learning_rate': 0.27928364114374715, 'subsample': 0.7000628513855395, 'colsample_bytree': 0.9607156503536007, 'gamma': 4.118546059430237, 'n_steps': 7, 'smap1': 10, 'smap2': 12, 'smap3': 46, 'smap4': 194, 'emap1': 9, 'emap2': 16, 'emap3': 49, 'emap4': 88, 'macd_fast': 14, 'macd_slow': 23, 'macd_signal': 11, 'rsi_window': 14, 'srsi_window': 18, 'srsi_k': 3, 'srsi_d': 4, 'roc_window': 15, 'mom_window': 15, 'cmf_window': 23, 'mfi_window': 10, 'bollinger_window': 22, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 13, 'donchian_window': 18, 'trix_window': 11, 'inc_fib': True, 'pc_window': 25, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:43:52,762] Trial 24 finished with value: 1.8008914155773876 and parameters: {'lags': 4, 'n_estimators': 155, 'max_depth': 4, 'learning_rate': 0.229437643174886, 'subsample': 0.8413541785087713, 'colsample_bytree': 0.8774991055249635, 'gamma': 3.001697259903754, 'n_steps': 1, 'smap1': 9, 'smap2': 14, 'smap3': 41, 'smap4': 138, 'emap1': 10, 'emap2': 14, 'emap3': 51, 'emap4': 91, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 10, 'rsi_window': 12, 'srsi_window': 15, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 17, 'mom_window': 12, 'cmf_window': 12, 'mfi_window': 12, 'bollinger_window': 18, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 20, 'trix_window': 13, 'inc_fib': True, 'pc_window': 19, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:44:31,518] Trial 25 finished with value: 3.613541080178087 and parameters: {'lags': 5, 'n_estimators': 155, 'max_depth': 4, 'learning_rate': 0.22482347596031754, 'subsample': 0.8496929506488917, 'colsample_bytree': 0.838018434643113, 'gamma': 2.7733957616147835, 'n_steps': 11, 'smap1': 9, 'smap2': 16, 'smap3': 41, 'smap4': 142, 'emap1': 10, 'emap2': 13, 'emap3': 47, 'emap4': 91, 'macd_fast': 14, 'macd_slow': 24, 'macd_signal': 10, 'rsi_window': 11, 'srsi_window': 13, 'srsi_k': 3, 'srsi_d': 3, 'roc_window': 17, 'mom_window': 12, 'cmf_window': 12, 'mfi_window': 11, 'bollinger_window': 17, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 17, 'donchian_window': 22, 'trix_window': 13, 'inc_fib': True, 'pc_window': 22, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:45:22,054] Trial 26 finished with value: 2.6708514173611544 and parameters: {'lags': 4, 'n_estimators': 201, 'max_depth': 4, 'learning_rate': 0.18233808688288722, 'subsample': 0.8935191827635178, 'colsample_bytree': 0.7774988069554774, 'gamma': 3.0863150119761915, 'n_steps': 6, 'smap1': 8, 'smap2': 11, 'smap3': 38, 'smap4': 120, 'emap1': 11, 'emap2': 15, 'emap3': 38, 'emap4': 81, 'macd_fast': 13, 'macd_slow': 22, 'macd_signal': 10, 'rsi_window': 12, 'srsi_window': 15, 'srsi_k': 4, 'srsi_d': 4, 'roc_window': 18, 'mom_window': 11, 'cmf_window': 14, 'mfi_window': 14, 'bollinger_window': 18, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 12, 'donchian_window': 21, 'trix_window': 12, 'inc_fib': True, 'pc_window': 23, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:45:51,118] Trial 27 finished with value: 4.668030823550354 and parameters: {'lags': 9, 'n_estimators': 121, 'max_depth': 5, 'learning_rate': 0.26552287364777877, 'subsample': 0.946050689772311, 'colsample_bytree': 0.9585433508309185, 'gamma': 4.2952874059212665, 'n_steps': 18, 'smap1': 9, 'smap2': 13, 'smap3': 37, 'smap4': 134, 'emap1': 5, 'emap2': 18, 'emap3': 45, 'emap4': 91, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 11, 'rsi_window': 12, 'srsi_window': 12, 'srsi_k': 3, 'srsi_d': 5, 'roc_window': 20, 'mom_window': 13, 'cmf_window': 11, 'mfi_window': 12, 'bollinger_window': 15, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 20, 'trix_window': 14, 'inc_fib': True, 'pc_window': 20, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:46:27,872] Trial 28 finished with value: 2.3338720268640816 and parameters: {'lags': 7, 'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.24070183048820984, 'subsample': 0.8281161603185653, 'colsample_bytree': 0.9223388669904093, 'gamma': 3.0344067820100484, 'n_steps': 3, 'smap1': 10, 'smap2': 12, 'smap3': 42, 'smap4': 148, 'emap1': 8, 'emap2': 14, 'emap3': 30, 'emap4': 97, 'macd_fast': 14, 'macd_slow': 24, 'macd_signal': 10, 'rsi_window': 16, 'srsi_window': 14, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 17, 'mom_window': 9, 'cmf_window': 15, 'mfi_window': 10, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 18, 'donchian_window': 17, 'trix_window': 13, 'inc_fib': True, 'pc_window': 15, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:47:14,311] Trial 29 finished with value: 3.577333031725304 and parameters: {'lags': 14, 'n_estimators': 189, 'max_depth': 5, 'learning_rate': 0.21714506183058574, 'subsample': 0.8826701478325452, 'colsample_bytree': 0.8753881245968025, 'gamma': 5.1927627125689435, 'n_steps': 10, 'smap1': 9, 'smap2': 11, 'smap3': 34, 'smap4': 119, 'emap1': 12, 'emap2': 20, 'emap3': 42, 'emap4': 86, 'macd_fast': 15, 'macd_slow': 30, 'macd_signal': 11, 'rsi_window': 11, 'srsi_window': 20, 'srsi_k': 4, 'srsi_d': 4, 'roc_window': 14, 'mom_window': 12, 'cmf_window': 12, 'mfi_window': 14, 'bollinger_window': 24, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 10, 'donchian_window': 25, 'trix_window': 14, 'inc_fib': True, 'pc_window': 18, 'inc_fractals': True}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:48:08,738] Trial 30 finished with value: 2.4726799796922423 and parameters: {'lags': 4, 'n_estimators': 235, 'max_depth': 2, 'learning_rate': 0.2742002100604922, 'subsample': 0.772508316165966, 'colsample_bytree': 0.9943046197178652, 'gamma': 1.8026349716717247, 'n_steps': 3, 'smap1': 6, 'smap2': 14, 'smap3': 31, 'smap4': 88, 'emap1': 10, 'emap2': 21, 'emap3': 49, 'emap4': 89, 'macd_fast': 12, 'macd_slow': 20, 'macd_signal': 7, 'rsi_window': 10, 'srsi_window': 15, 'srsi_k': 4, 'srsi_d': 3, 'roc_window': 16, 'mom_window': 11, 'cmf_window': 13, 'mfi_window': 11, 'bollinger_window': 17, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 16, 'donchian_window': 23, 'trix_window': 11, 'inc_fib': True, 'pc_window': 28, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:48:34,071] Trial 31 finished with value: 2.2756017890195808 and parameters: {'lags': 5, 'n_estimators': 78, 'max_depth': 3, 'learning_rate': 0.29748653282117316, 'subsample': 0.7459965557851205, 'colsample_bytree': 0.8111671876319992, 'gamma': 5.129026276850679, 'n_steps': 2, 'smap1': 10, 'smap2': 14, 'smap3': 45, 'smap4': 169, 'emap1': 9, 'emap2': 16, 'emap3': 51, 'emap4': 98, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 14, 'srsi_window': 16, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 15, 'mom_window': 14, 'cmf_window': 17, 'mfi_window': 12, 'bollinger_window': 21, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 19, 'trix_window': 11, 'inc_fib': True, 'pc_window': 18, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:49:09,087] Trial 32 finished with value: 1.9575261180437502 and parameters: {'lags': 20, 'n_estimators': 95, 'max_depth': 3, 'learning_rate': 0.2422174996496786, 'subsample': 0.7210778245224131, 'colsample_bytree': 0.9013728409795129, 'gamma': 5.860936730194381, 'n_steps': 1, 'smap1': 11, 'smap2': 16, 'smap3': 49, 'smap4': 154, 'emap1': 11, 'emap2': 14, 'emap3': 50, 'emap4': 97, 'macd_fast': 15, 'macd_slow': 22, 'macd_signal': 12, 'rsi_window': 15, 'srsi_window': 18, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 14, 'cmf_window': 18, 'mfi_window': 13, 'bollinger_window': 24, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 15, 'donchian_window': 19, 'trix_window': 10, 'inc_fib': True, 'pc_window': 20, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:49:39,932] Trial 33 finished with value: 4.082325025267176 and parameters: {'lags': 7, 'n_estimators': 76, 'max_depth': 3, 'learning_rate': 0.037853886717040056, 'subsample': 0.6113380567027925, 'colsample_bytree': 0.8700875835497801, 'gamma': 4.260375774512195, 'n_steps': 6, 'smap1': 9, 'smap2': 13, 'smap3': 46, 'smap4': 141, 'emap1': 7, 'emap2': 17, 'emap3': 48, 'emap4': 94, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 11, 'rsi_window': 13, 'srsi_window': 14, 'srsi_k': 3, 'srsi_d': 5, 'roc_window': 14, 'mom_window': 13, 'cmf_window': 15, 'mfi_window': 12, 'bollinger_window': 21, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 14, 'donchian_window': 17, 'trix_window': 12, 'inc_fib': True, 'pc_window': 18, 'inc_fractals': False}. Best is trial 13 with value: 1.7965905833074474.
# [I 2025-07-31 23:50:18,428] Trial 34 finished with value: 1.782947841467823 and parameters: {'lags': 5, 'n_estimators': 115, 'max_depth': 4, 'learning_rate': 0.27780565566498333, 'subsample': 0.7873318165122818, 'colsample_bytree': 0.9571312217288321, 'gamma': 3.9287301552120275, 'n_steps': 1, 'smap1': 10, 'smap2': 16, 'smap3': 41, 'smap4': 184, 'emap1': 10, 'emap2': 19, 'emap3': 46, 'emap4': 83, 'macd_fast': 14, 'macd_slow': 23, 'macd_signal': 12, 'rsi_window': 17, 'srsi_window': 17, 'srsi_k': 4, 'srsi_d': 4, 'roc_window': 15, 'mom_window': 15, 'cmf_window': 30, 'mfi_window': 15, 'bollinger_window': 25, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 13, 'donchian_window': 21, 'trix_window': 11, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:50:46,893] Trial 35 finished with value: 2.453089380770121 and parameters: {'lags': 7, 'n_estimators': 117, 'max_depth': 4, 'learning_rate': 0.2773287371412989, 'subsample': 0.8658883990729629, 'colsample_bytree': 0.9606073183844349, 'gamma': 3.2800403201034323, 'n_steps': 4, 'smap1': 8, 'smap2': 17, 'smap3': 40, 'smap4': 199, 'emap1': 12, 'emap2': 19, 'emap3': 46, 'emap4': 83, 'macd_fast': 13, 'macd_slow': 23, 'macd_signal': 11, 'rsi_window': 18, 'srsi_window': 17, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 18, 'mom_window': 15, 'cmf_window': 28, 'mfi_window': 17, 'bollinger_window': 25, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 12, 'donchian_window': 22, 'trix_window': 17, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': True}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:51:31,958] Trial 36 finished with value: 3.911681396801066 and parameters: {'lags': 4, 'n_estimators': 169, 'max_depth': 5, 'learning_rate': 0.12843777177537527, 'subsample': 0.9412781273946875, 'colsample_bytree': 0.9392466398725102, 'gamma': 3.973598538399903, 'n_steps': 13, 'smap1': 10, 'smap2': 18, 'smap3': 37, 'smap4': 52, 'emap1': 10, 'emap2': 22, 'emap3': 47, 'emap4': 79, 'macd_fast': 14, 'macd_slow': 22, 'macd_signal': 10, 'rsi_window': 16, 'srsi_window': 19, 'srsi_k': 3, 'srsi_d': 4, 'roc_window': 19, 'mom_window': 15, 'cmf_window': 30, 'mfi_window': 19, 'bollinger_window': 26, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 13, 'donchian_window': 21, 'trix_window': 12, 'inc_fib': False, 'pc_window': 15, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:52:09,527] Trial 37 finished with value: 3.0639649608458583 and parameters: {'lags': 6, 'n_estimators': 140, 'max_depth': 5, 'learning_rate': 0.25120913201154554, 'subsample': 0.8149010231328261, 'colsample_bytree': 0.9709888567204945, 'gamma': 4.498493165218131, 'n_steps': 7, 'smap1': 7, 'smap2': 15, 'smap3': 33, 'smap4': 185, 'emap1': 11, 'emap2': 19, 'emap3': 44, 'emap4': 85, 'macd_fast': 12, 'macd_slow': 23, 'macd_signal': 12, 'rsi_window': 17, 'srsi_window': 15, 'srsi_k': 4, 'srsi_d': 2, 'roc_window': 13, 'mom_window': 12, 'cmf_window': 23, 'mfi_window': 16, 'bollinger_window': 19, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 24, 'trix_window': 10, 'inc_fib': False, 'pc_window': 17, 'inc_fractals': True}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:52:39,741] Trial 38 finished with value: 4.214378465525247 and parameters: {'lags': 9, 'n_estimators': 116, 'max_depth': 4, 'learning_rate': 0.22784078608160754, 'subsample': 0.7758179155468997, 'colsample_bytree': 0.714187379622758, 'gamma': 2.527048119193127, 'n_steps': 16, 'smap1': 7, 'smap2': 16, 'smap3': 43, 'smap4': 126, 'emap1': 10, 'emap2': 13, 'emap3': 38, 'emap4': 77, 'macd_fast': 11, 'macd_slow': 20, 'macd_signal': 10, 'rsi_window': 18, 'srsi_window': 12, 'srsi_k': 2, 'srsi_d': 4, 'roc_window': 17, 'mom_window': 13, 'cmf_window': 11, 'mfi_window': 15, 'bollinger_window': 24, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 12, 'donchian_window': 28, 'trix_window': 20, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:53:32,885] Trial 39 finished with value: 2.541216413626712 and parameters: {'lags': 3, 'n_estimators': 223, 'max_depth': 2, 'learning_rate': 0.09113945297610486, 'subsample': 0.8381056044045849, 'colsample_bytree': 0.8505877998671396, 'gamma': 4.836844972335063, 'n_steps': 3, 'smap1': 10, 'smap2': 12, 'smap3': 41, 'smap4': 114, 'emap1': 13, 'emap2': 18, 'emap3': 42, 'emap4': 67, 'macd_fast': 13, 'macd_slow': 25, 'macd_signal': 11, 'rsi_window': 18, 'srsi_window': 13, 'srsi_k': 3, 'srsi_d': 4, 'roc_window': 10, 'mom_window': 9, 'cmf_window': 25, 'mfi_window': 14, 'bollinger_window': 16, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 16, 'donchian_window': 25, 'trix_window': 16, 'inc_fib': False, 'pc_window': 30, 'inc_fractals': True}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:54:27,489] Trial 40 finished with value: 5.328484724183442 and parameters: {'lags': 8, 'n_estimators': 258, 'max_depth': 6, 'learning_rate': 0.2806998135666892, 'subsample': 0.9314697836691591, 'colsample_bytree': 0.9258361142394478, 'gamma': 0.7815752985411515, 'n_steps': 23, 'smap1': 3, 'smap2': 18, 'smap3': 21, 'smap4': 93, 'emap1': 11, 'emap2': 15, 'emap3': 31, 'emap4': 86, 'macd_fast': 14, 'macd_slow': 24, 'macd_signal': 12, 'rsi_window': 12, 'srsi_window': 17, 'srsi_k': 4, 'srsi_d': 3, 'roc_window': 14, 'mom_window': 14, 'cmf_window': 30, 'mfi_window': 10, 'bollinger_window': 26, 'bollinger_num_std': 3, 'inc_obv': False, 'atr_window': 13, 'donchian_window': 23, 'trix_window': 11, 'inc_fib': False, 'pc_window': 22, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:54:59,462] Trial 41 finished with value: 1.909008276336061 and parameters: {'lags': 5, 'n_estimators': 87, 'max_depth': 3, 'learning_rate': 0.2985995437635369, 'subsample': 0.8750267150709854, 'colsample_bytree': 0.9084157008603799, 'gamma': 5.431512525456115, 'n_steps': 1, 'smap1': 11, 'smap2': 14, 'smap3': 48, 'smap4': 187, 'emap1': 9, 'emap2': 17, 'emap3': 50, 'emap4': 91, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 17, 'srsi_window': 16, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 15, 'mom_window': 14, 'cmf_window': 19, 'mfi_window': 13, 'bollinger_window': 21, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 11, 'inc_fib': False, 'pc_window': 20, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:55:34,979] Trial 42 finished with value: 1.8858226687099953 and parameters: {'lags': 5, 'n_estimators': 99, 'max_depth': 4, 'learning_rate': 0.26578668677659006, 'subsample': 0.9977492919738964, 'colsample_bytree': 0.9023891193399585, 'gamma': 3.7210739199133256, 'n_steps': 1, 'smap1': 11, 'smap2': 13, 'smap3': 48, 'smap4': 184, 'emap1': 10, 'emap2': 17, 'emap3': 50, 'emap4': 90, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 17, 'srsi_window': 16, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 14, 'cmf_window': 20, 'mfi_window': 15, 'bollinger_window': 20, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 12, 'inc_fib': False, 'pc_window': 20, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:56:04,753] Trial 43 finished with value: 2.5188611873002635 and parameters: {'lags': 4, 'n_estimators': 128, 'max_depth': 4, 'learning_rate': 0.2674663024933599, 'subsample': 0.999657083224903, 'colsample_bytree': 0.8224865276216196, 'gamma': 3.7763021964188312, 'n_steps': 4, 'smap1': 11, 'smap2': 13, 'smap3': 44, 'smap4': 175, 'emap1': 10, 'emap2': 19, 'emap3': 48, 'emap4': 89, 'macd_fast': 14, 'macd_slow': 28, 'macd_signal': 12, 'rsi_window': 19, 'srsi_window': 18, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 15, 'cmf_window': 22, 'mfi_window': 15, 'bollinger_window': 19, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 14, 'donchian_window': 22, 'trix_window': 13, 'inc_fib': False, 'pc_window': 17, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:56:27,737] Trial 44 finished with value: 2.283233034017881 and parameters: {'lags': 6, 'n_estimators': 68, 'max_depth': 4, 'learning_rate': 0.2511607393969325, 'subsample': 0.9074456575141367, 'colsample_bytree': 0.9747379284360417, 'gamma': 2.780825678148883, 'n_steps': 2, 'smap1': 10, 'smap2': 13, 'smap3': 48, 'smap4': 129, 'emap1': 11, 'emap2': 15, 'emap3': 51, 'emap4': 84, 'macd_fast': 15, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 16, 'srsi_window': 17, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 18, 'mom_window': 13, 'cmf_window': 28, 'mfi_window': 17, 'bollinger_window': 18, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 13, 'donchian_window': 18, 'trix_window': 12, 'inc_fib': False, 'pc_window': 20, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:56:58,785] Trial 45 finished with value: 3.237984105949804 and parameters: {'lags': 3, 'n_estimators': 103, 'max_depth': 4, 'learning_rate': 0.1795130298197556, 'subsample': 0.7934833763115392, 'colsample_bytree': 0.572327718783875, 'gamma': 3.4897204352383087, 'n_steps': 8, 'smap1': 9, 'smap2': 12, 'smap3': 40, 'smap4': 183, 'emap1': 8, 'emap2': 17, 'emap3': 50, 'emap4': 74, 'macd_fast': 15, 'macd_slow': 22, 'macd_signal': 8, 'rsi_window': 17, 'srsi_window': 19, 'srsi_k': 4, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 14, 'cmf_window': 13, 'mfi_window': 16, 'bollinger_window': 18, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 10, 'inc_fib': False, 'pc_window': 25, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:57:35,204] Trial 46 finished with value: 2.8766431934034844 and parameters: {'lags': 7, 'n_estimators': 160, 'max_depth': 5, 'learning_rate': 0.28293778928753466, 'subsample': 0.9580917513833166, 'colsample_bytree': 0.9496997674398733, 'gamma': 4.5473298688746455, 'n_steps': 6, 'smap1': 11, 'smap2': 20, 'smap3': 42, 'smap4': 199, 'emap1': 10, 'emap2': 20, 'emap3': 48, 'emap4': 87, 'macd_fast': 14, 'macd_slow': 23, 'macd_signal': 11, 'rsi_window': 18, 'srsi_window': 16, 'srsi_k': 2, 'srsi_d': 4, 'roc_window': 17, 'mom_window': 10, 'cmf_window': 26, 'mfi_window': 15, 'bollinger_window': 19, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 16, 'donchian_window': 21, 'trix_window': 12, 'inc_fib': False, 'pc_window': 22, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:58:04,126] Trial 47 finished with value: 2.3339958883411143 and parameters: {'lags': 13, 'n_estimators': 96, 'max_depth': 4, 'learning_rate': 0.2293294052578221, 'subsample': 0.9990701488394136, 'colsample_bytree': 0.9949905904875073, 'gamma': 2.077509082642458, 'n_steps': 2, 'smap1': 9, 'smap2': 16, 'smap3': 45, 'smap4': 170, 'emap1': 5, 'emap2': 14, 'emap3': 46, 'emap4': 93, 'macd_fast': 11, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 20, 'srsi_window': 14, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 12, 'mom_window': 6, 'cmf_window': 20, 'mfi_window': 18, 'bollinger_window': 28, 'bollinger_num_std': 3, 'inc_obv': False, 'atr_window': 12, 'donchian_window': 17, 'trix_window': 15, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-07-31 23:59:16,397] Trial 48 finished with value: 6.3649124815165825 and parameters: {'lags': 4, 'n_estimators': 182, 'max_depth': 4, 'learning_rate': 0.010002113661545103, 'subsample': 0.6623765807280504, 'colsample_bytree': 0.8569065927952234, 'gamma': 3.236469959858554, 'n_steps': 4, 'smap1': 6, 'smap2': 15, 'smap3': 25, 'smap4': 153, 'emap1': 6, 'emap2': 18, 'emap3': 49, 'emap4': 80, 'macd_fast': 13, 'macd_slow': 21, 'macd_signal': 11, 'rsi_window': 16, 'srsi_window': 15, 'srsi_k': 5, 'srsi_d': 5, 'roc_window': 13, 'mom_window': 11, 'cmf_window': 15, 'mfi_window': 17, 'bollinger_window': 23, 'bollinger_num_std': 3, 'inc_obv': False, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 19, 'inc_fib': False, 'pc_window': 21, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:00:02,290] Trial 49 finished with value: 2.0403117879117065 and parameters: {'lags': 17, 'n_estimators': 143, 'max_depth': 5, 'learning_rate': 0.26767678726311184, 'subsample': 0.812801177583007, 'colsample_bytree': 0.9127088826072625, 'gamma': 3.8823867774098826, 'n_steps': 1, 'smap1': 10, 'smap2': 17, 'smap3': 38, 'smap4': 193, 'emap1': 10, 'emap2': 22, 'emap3': 51, 'emap4': 99, 'macd_fast': 15, 'macd_slow': 29, 'macd_signal': 9, 'rsi_window': 19, 'srsi_window': 15, 'srsi_k': 3, 'srsi_d': 2, 'roc_window': 15, 'mom_window': 15, 'cmf_window': 10, 'mfi_window': 14, 'bollinger_window': 20, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 15, 'donchian_window': 15, 'trix_window': 10, 'inc_fib': False, 'pc_window': 24, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:00:17,289] Trial 50 finished with value: 2.6400772187223844 and parameters: {'lags': 9, 'n_estimators': 54, 'max_depth': 3, 'learning_rate': 0.2876678524420914, 'subsample': 0.9227060601344815, 'colsample_bytree': 0.9363367849282925, 'gamma': 4.889647460713544, 'n_steps': 5, 'smap1': 11, 'smap2': 11, 'smap3': 47, 'smap4': 147, 'emap1': 8, 'emap2': 24, 'emap3': 40, 'emap4': 95, 'macd_fast': 14, 'macd_slow': 22, 'macd_signal': 12, 'rsi_window': 15, 'srsi_window': 16, 'srsi_k': 5, 'srsi_d': 3, 'roc_window': 16, 'mom_window': 13, 'cmf_window': 17, 'mfi_window': 11, 'bollinger_window': 21, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 14, 'inc_fib': True, 'pc_window': 23, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:00:49,262] Trial 51 finished with value: 1.9409297453397383 and parameters: {'lags': 5, 'n_estimators': 88, 'max_depth': 3, 'learning_rate': 0.2986115580534705, 'subsample': 0.8793091523564516, 'colsample_bytree': 0.8975981726197211, 'gamma': 6.219348002866793, 'n_steps': 1, 'smap1': 11, 'smap2': 14, 'smap3': 49, 'smap4': 187, 'emap1': 9, 'emap2': 17, 'emap3': 50, 'emap4': 90, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 17, 'srsi_window': 16, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 15, 'mom_window': 14, 'cmf_window': 21, 'mfi_window': 13, 'bollinger_window': 21, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 11, 'inc_fib': False, 'pc_window': 20, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:01:20,529] Trial 52 finished with value: 2.25888245921412 and parameters: {'lags': 5, 'n_estimators': 116, 'max_depth': 3, 'learning_rate': 0.28663798480309827, 'subsample': 0.8684821596779777, 'colsample_bytree': 0.9725660361056445, 'gamma': 5.374104254675535, 'n_steps': 2, 'smap1': 11, 'smap2': 13, 'smap3': 50, 'smap4': 180, 'emap1': 9, 'emap2': 17, 'emap3': 50, 'emap4': 92, 'macd_fast': 15, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 17, 'srsi_window': 17, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 15, 'cmf_window': 16, 'mfi_window': 13, 'bollinger_window': 20, 'bollinger_num_std': 3, 'inc_obv': False, 'atr_window': 13, 'donchian_window': 21, 'trix_window': 12, 'inc_fib': False, 'pc_window': 19, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:01:39,399] Trial 53 finished with value: 2.569399934703378 and parameters: {'lags': 6, 'n_estimators': 68, 'max_depth': 2, 'learning_rate': 0.27078454430302107, 'subsample': 0.8500336839915172, 'colsample_bytree': 0.8699737888097129, 'gamma': 4.319411551721228, 'n_steps': 3, 'smap1': 10, 'smap2': 15, 'smap3': 48, 'smap4': 137, 'emap1': 10, 'emap2': 18, 'emap3': 47, 'emap4': 101, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 16, 'srsi_window': 16, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 17, 'mom_window': 14, 'cmf_window': 19, 'mfi_window': 15, 'bollinger_window': 22, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 15, 'donchian_window': 18, 'trix_window': 11, 'inc_fib': False, 'pc_window': 21, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:02:15,129] Trial 54 finished with value: 1.9616666198193036 and parameters: {'lags': 3, 'n_estimators': 105, 'max_depth': 3, 'learning_rate': 0.25347492398045773, 'subsample': 0.9022393837579541, 'colsample_bytree': 0.9041189021458165, 'gamma': 6.252912653310175, 'n_steps': 1, 'smap1': 11, 'smap2': 14, 'smap3': 44, 'smap4': 190, 'emap1': 7, 'emap2': 19, 'emap3': 49, 'emap4': 96, 'macd_fast': 15, 'macd_slow': 20, 'macd_signal': 12, 'rsi_window': 17, 'srsi_window': 18, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 15, 'mom_window': 13, 'cmf_window': 19, 'mfi_window': 12, 'bollinger_window': 29, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 14, 'donchian_window': 20, 'trix_window': 10, 'inc_fib': False, 'pc_window': 20, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:02:35,642] Trial 55 finished with value: 2.684587795745253 and parameters: {'lags': 8, 'n_estimators': 84, 'max_depth': 3, 'learning_rate': 0.28754046681628437, 'subsample': 0.7950430327442682, 'colsample_bytree': 0.9429423330754322, 'gamma': 4.999081658235219, 'n_steps': 5, 'smap1': 10, 'smap2': 13, 'smap3': 47, 'smap4': 164, 'emap1': 9, 'emap2': 16, 'emap3': 51, 'emap4': 88, 'macd_fast': 14, 'macd_slow': 22, 'macd_signal': 11, 'rsi_window': 15, 'srsi_window': 15, 'srsi_k': 4, 'srsi_d': 5, 'roc_window': 14, 'mom_window': 12, 'cmf_window': 20, 'mfi_window': 11, 'bollinger_window': 21, 'bollinger_num_std': 3, 'inc_obv': False, 'atr_window': 20, 'donchian_window': 22, 'trix_window': 11, 'inc_fib': False, 'pc_window': 19, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:03:06,971] Trial 56 finished with value: 2.434056755996369 and parameters: {'lags': 5, 'n_estimators': 129, 'max_depth': 4, 'learning_rate': 0.29831651735242637, 'subsample': 0.7509697818926225, 'colsample_bytree': 0.7920124103747688, 'gamma': 5.540454696884588, 'n_steps': 3, 'smap1': 9, 'smap2': 12, 'smap3': 43, 'smap4': 177, 'emap1': 9, 'emap2': 15, 'emap3': 48, 'emap4': 93, 'macd_fast': 15, 'macd_slow': 21, 'macd_signal': 12, 'rsi_window': 16, 'srsi_window': 17, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 15, 'mom_window': 14, 'cmf_window': 13, 'mfi_window': 16, 'bollinger_window': 23, 'bollinger_num_std': 2, 'inc_obv': True, 'atr_window': 17, 'donchian_window': 19, 'trix_window': 13, 'inc_fib': True, 'pc_window': 18, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# [I 2025-08-01 00:03:41,234] Trial 57 finished with value: 1.8649580087287128 and parameters: {'lags': 4, 'n_estimators': 63, 'max_depth': 3, 'learning_rate': 0.1422119862461396, 'subsample': 0.8256083370197901, 'colsample_bytree': 0.6517638132572312, 'gamma': 4.637785866934497, 'n_steps': 1, 'smap1': 11, 'smap2': 14, 'smap3': 41, 'smap4': 170, 'emap1': 8, 'emap2': 20, 'emap3': 50, 'emap4': 90, 'macd_fast': 10, 'macd_slow': 22, 'macd_signal': 11, 'rsi_window': 18, 'srsi_window': 16, 'srsi_k': 3, 'srsi_d': 5, 'roc_window': 16, 'mom_window': 15, 'cmf_window': 14, 'mfi_window': 13, 'bollinger_window': 28, 'bollinger_num_std': 1, 'inc_obv': True, 'atr_window': 13, 'donchian_window': 18, 'trix_window': 12, 'inc_fib': True, 'pc_window': 16, 'inc_fractals': False}. Best is trial 34 with value: 1.782947841467823.
# ...
# [I 2025-08-01 06:15:23,858] Trial 582 finished with value: 2.195375085659239 and parameters: {'lags': 14, 'n_estimators': 279, 'max_depth': 5, 'learning_rate': 0.2705775712316105, 'subsample': 0.7256105681023993, 'colsample_bytree': 0.7966725836929077, 'gamma': 0.851665102802341, 'n_steps': 3, 'smap1': 9, 'smap2': 15, 'smap3': 46, 'smap4': 185, 'emap1': 6, 'emap2': 21, 'emap3': 32, 'emap4': 51, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 7, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 29, 'mfi_window': 14, 'bollinger_window': 21, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 19, 'inc_fib': False, 'pc_window': 15, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:16:19,732] Trial 583 finished with value: 1.493847202089871 and parameters: {'lags': 3, 'n_estimators': 229, 'max_depth': 5, 'learning_rate': 0.27837769892892206, 'subsample': 0.7341525134274262, 'colsample_bytree': 0.7661303464210487, 'gamma': 0.8281392469491295, 'n_steps': 1, 'smap1': 9, 'smap2': 14, 'smap3': 45, 'smap4': 183, 'emap1': 6, 'emap2': 20, 'emap3': 32, 'emap4': 53, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 23, 'mfi_window': 14, 'bollinger_window': 19, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 16, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:17:11,868] Trial 584 finished with value: 2.0254165995342066 and parameters: {'lags': 12, 'n_estimators': 222, 'max_depth': 5, 'learning_rate': 0.2791434044903645, 'subsample': 0.7596825454524109, 'colsample_bytree': 0.7628524224310528, 'gamma': 0.7886199558333256, 'n_steps': 2, 'smap1': 9, 'smap2': 14, 'smap3': 45, 'smap4': 182, 'emap1': 6, 'emap2': 21, 'emap3': 32, 'emap4': 53, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 11, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 17, 'mom_window': 5, 'cmf_window': 28, 'mfi_window': 13, 'bollinger_window': 19, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 18, 'trix_window': 16, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:18:06,578] Trial 585 finished with value: 1.5418480991354184 and parameters: {'lags': 3, 'n_estimators': 220, 'max_depth': 5, 'learning_rate': 0.28224290499899063, 'subsample': 0.744308266955648, 'colsample_bytree': 0.7713162086677305, 'gamma': 0.8141024356712594, 'n_steps': 1, 'smap1': 9, 'smap2': 14, 'smap3': 46, 'smap4': 183, 'emap1': 6, 'emap2': 20, 'emap3': 32, 'emap4': 54, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 23, 'mfi_window': 14, 'bollinger_window': 19, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 10, 'donchian_window': 19, 'trix_window': 16, 'inc_fib': False, 'pc_window': 17, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:19:00,636] Trial 586 finished with value: 1.8968480101932037 and parameters: {'lags': 4, 'n_estimators': 229, 'max_depth': 5, 'learning_rate': 0.27457401399531683, 'subsample': 0.7712146442552629, 'colsample_bytree': 0.7603186144773645, 'gamma': 0.6158914624934912, 'n_steps': 2, 'smap1': 9, 'smap2': 14, 'smap3': 47, 'smap4': 181, 'emap1': 6, 'emap2': 21, 'emap3': 32, 'emap4': 53, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 29, 'mfi_window': 14, 'bollinger_window': 19, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 18, 'trix_window': 16, 'inc_fib': False, 'pc_window': 17, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:19:55,025] Trial 587 finished with value: 1.5678962905078742 and parameters: {'lags': 3, 'n_estimators': 224, 'max_depth': 5, 'learning_rate': 0.280714004140637, 'subsample': 0.7393362327829571, 'colsample_bytree': 0.7549559868590024, 'gamma': 1.0374286176852363, 'n_steps': 1, 'smap1': 9, 'smap2': 13, 'smap3': 49, 'smap4': 180, 'emap1': 6, 'emap2': 20, 'emap3': 32, 'emap4': 54, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 28, 'mfi_window': 14, 'bollinger_window': 19, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 17, 'trix_window': 16, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:20:51,041] Trial 588 finished with value: 1.571146137685673 and parameters: {'lags': 3, 'n_estimators': 229, 'max_depth': 5, 'learning_rate': 0.2649450427697183, 'subsample': 0.7317870755536217, 'colsample_bytree': 0.7763639581301073, 'gamma': 0.7782615093888439, 'n_steps': 1, 'smap1': 9, 'smap2': 14, 'smap3': 48, 'smap4': 158, 'emap1': 6, 'emap2': 20, 'emap3': 32, 'emap4': 57, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 24, 'mfi_window': 13, 'bollinger_window': 19, 'bollinger_num_std': 2, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 16, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:21:44,421] Trial 589 finished with value: 2.105553840063511 and parameters: {'lags': 3, 'n_estimators': 262, 'max_depth': 5, 'learning_rate': 0.27695482055003257, 'subsample': 0.7325759831744725, 'colsample_bytree': 0.7668310794944899, 'gamma': 0.9491726928441824, 'n_steps': 3, 'smap1': 9, 'smap2': 14, 'smap3': 44, 'smap4': 162, 'emap1': 6, 'emap2': 27, 'emap3': 31, 'emap4': 52, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 16, 'mfi_window': 14, 'bollinger_window': 19, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 16, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:22:34,465] Trial 590 finished with value: 3.74030390689855 and parameters: {'lags': 4, 'n_estimators': 230, 'max_depth': 5, 'learning_rate': 0.26928462830744393, 'subsample': 0.7530815289328054, 'colsample_bytree': 0.7818046457660968, 'gamma': 1.970607000805856, 'n_steps': 13, 'smap1': 9, 'smap2': 14, 'smap3': 45, 'smap4': 147, 'emap1': 6, 'emap2': 21, 'emap3': 31, 'emap4': 53, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 29, 'mfi_window': 12, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 18, 'trix_window': 18, 'inc_fib': False, 'pc_window': 17, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:23:38,749] Trial 591 finished with value: 1.6426080673392451 and parameters: {'lags': 16, 'n_estimators': 267, 'max_depth': 5, 'learning_rate': 0.2859960292250786, 'subsample': 0.7218050775629843, 'colsample_bytree': 0.7516342973791822, 'gamma': 0.666597211493652, 'n_steps': 1, 'smap1': 9, 'smap2': 14, 'smap3': 45, 'smap4': 178, 'emap1': 6, 'emap2': 20, 'emap3': 33, 'emap4': 52, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 10, 'rsi_window': 19, 'srsi_window': 11, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 17, 'mom_window': 5, 'cmf_window': 30, 'mfi_window': 14, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 16, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:24:36,898] Trial 592 finished with value: 1.8738393788083356 and parameters: {'lags': 3, 'n_estimators': 240, 'max_depth': 5, 'learning_rate': 0.2743131898306115, 'subsample': 0.6714739551672639, 'colsample_bytree': 0.7905783799889151, 'gamma': 1.121285004528287, 'n_steps': 2, 'smap1': 9, 'smap2': 13, 'smap3': 46, 'smap4': 173, 'emap1': 6, 'emap2': 20, 'emap3': 32, 'emap4': 54, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 28, 'mfi_window': 13, 'bollinger_window': 23, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 14, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:25:31,846] Trial 593 finished with value: 1.5861336871117777 and parameters: {'lags': 3, 'n_estimators': 224, 'max_depth': 5, 'learning_rate': 0.28018385328351875, 'subsample': 0.7383384491565353, 'colsample_bytree': 0.7763121308972329, 'gamma': 0.8260189039325181, 'n_steps': 1, 'smap1': 9, 'smap2': 14, 'smap3': 47, 'smap4': 166, 'emap1': 6, 'emap2': 20, 'emap3': 33, 'emap4': 56, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 3, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 30, 'mfi_window': 14, 'bollinger_window': 21, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 10, 'donchian_window': 18, 'trix_window': 16, 'inc_fib': False, 'pc_window': 15, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:26:28,157] Trial 594 finished with value: 1.8575744720650353 and parameters: {'lags': 3, 'n_estimators': 232, 'max_depth': 5, 'learning_rate': 0.2667900569913174, 'subsample': 0.6723967201389489, 'colsample_bytree': 0.7644545886515277, 'gamma': 0.5172580643596819, 'n_steps': 2, 'smap1': 9, 'smap2': 14, 'smap3': 49, 'smap4': 170, 'emap1': 7, 'emap2': 20, 'emap3': 31, 'emap4': 52, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 29, 'mfi_window': 14, 'bollinger_window': 19, 'bollinger_num_std': 3, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 16, 'inc_fib': False, 'pc_window': 17, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:27:23,541] Trial 595 finished with value: 1.6730380651356 and parameters: {'lags': 20, 'n_estimators': 220, 'max_depth': 5, 'learning_rate': 0.2863742567045471, 'subsample': 0.7265657776816472, 'colsample_bytree': 0.7833262890803129, 'gamma': 0.9659982754370785, 'n_steps': 1, 'smap1': 9, 'smap2': 15, 'smap3': 46, 'smap4': 163, 'emap1': 6, 'emap2': 19, 'emap3': 33, 'emap4': 53, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 21, 'mfi_window': 14, 'bollinger_window': 22, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 14, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:28:20,236] Trial 596 finished with value: 1.973696563571368 and parameters: {'lags': 4, 'n_estimators': 247, 'max_depth': 5, 'learning_rate': 0.27317693937780313, 'subsample': 0.6931464725893874, 'colsample_bytree': 0.7699497749382033, 'gamma': 1.2593705804736075, 'n_steps': 2, 'smap1': 9, 'smap2': 14, 'smap3': 45, 'smap4': 185, 'emap1': 6, 'emap2': 19, 'emap3': 32, 'emap4': 55, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 22, 'mfi_window': 14, 'bollinger_window': 19, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 17, 'inc_fib': False, 'pc_window': 16, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:29:15,595] Trial 597 finished with value: 1.4863295276793138 and parameters: {'lags': 3, 'n_estimators': 218, 'max_depth': 5, 'learning_rate': 0.2818990551217534, 'subsample': 0.682511585660972, 'colsample_bytree': 0.7425070524335181, 'gamma': 0.6497199095876447, 'n_steps': 1, 'smap1': 9, 'smap2': 15, 'smap3': 48, 'smap4': 156, 'emap1': 6, 'emap2': 19, 'emap3': 31, 'emap4': 51, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 30, 'mfi_window': 14, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 18, 'trix_window': 16, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:30:15,469] Trial 598 finished with value: 1.6523825897095703 and parameters: {'lags': 4, 'n_estimators': 218, 'max_depth': 5, 'learning_rate': 0.2834358451237742, 'subsample': 0.516915797162494, 'colsample_bytree': 0.7397463950179496, 'gamma': 0.604071663639046, 'n_steps': 1, 'smap1': 9, 'smap2': 15, 'smap3': 48, 'smap4': 154, 'emap1': 6, 'emap2': 19, 'emap3': 31, 'emap4': 51, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 30, 'mfi_window': 14, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 18, 'trix_window': 16, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# [I 2025-08-01 06:31:03,210] Trial 599 finished with value: 2.062800515038616 and parameters: {'lags': 3, 'n_estimators': 218, 'max_depth': 5, 'learning_rate': 0.2881724764595105, 'subsample': 0.6806746523488016, 'colsample_bytree': 0.7403751660183923, 'gamma': 0.5039424172852874, 'n_steps': 3, 'smap1': 9, 'smap2': 15, 'smap3': 43, 'smap4': 150, 'emap1': 6, 'emap2': 19, 'emap3': 31, 'emap4': 51, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 20, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 16, 'mom_window': 5, 'cmf_window': 29, 'mfi_window': 14, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 17, 'trix_window': 16, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}. Best is trial 506 with value: 1.4830756861071281.
# Best hyperparameters:  {'lags': 3, 'n_estimators': 231, 'max_depth': 5, 'learning_rate': 0.26993578453433226, 'subsample': 0.7008410761451417, 'colsample_bytree': 0.8023893379198315, 'gamma': 0.9053595826559675, 'n_steps': 1, 'smap1': 10, 'smap2': 15, 'smap3': 45, 'smap4': 163, 'emap1': 6, 'emap2': 18, 'emap3': 31, 'emap4': 52, 'macd_fast': 15, 'macd_slow': 25, 'macd_signal': 8, 'rsi_window': 10, 'srsi_window': 10, 'srsi_k': 5, 'srsi_d': 4, 'roc_window': 15, 'mom_window': 5, 'cmf_window': 30, 'mfi_window': 14, 'bollinger_window': 20, 'bollinger_num_std': 1, 'inc_obv': False, 'atr_window': 11, 'donchian_window': 19, 'trix_window': 17, 'inc_fib': False, 'pc_window': 18, 'inc_fractals': True}

# %% [markdown]
# ## Showing Results

# %%
print("Best trial:")
trial = study.best_trial
print(f"    RMSE: {trial.value}")
print("    Params:")
for key, value in trial.params.items():
    print(f"        {key}: {value}")
# Out:
# Best trial:
#     RMSSE: 1.4830756861071281
#     Params:
#         lags: 3
#         n_estimators: 231
#         max_depth: 5
#         learning_rate: 0.26993578453433226
#         subsample: 0.7008410761451417
#         colsample_bytree: 0.8023893379198315
#         gamma: 0.9053595826559675
#         n_steps: 1
#         smap1: 10
#         smap2: 15
#         smap3: 45
#         smap4: 163
#         emap1: 6
#         emap2: 18
#         emap3: 31
#         emap4: 52
#         macd_fast: 15
#         macd_slow: 25
#         macd_signal: 8
#         rsi_window: 10
#         srsi_window: 10
#         srsi_k: 5
#         srsi_d: 4
#         roc_window: 15
#         mom_window: 5
#         cmf_window: 30
#         mfi_window: 14
#         bollinger_window: 20
#         bollinger_num_std: 1
#         inc_obv: False
#         atr_window: 11
#         donchian_window: 19
#         trix_window: 17
#         inc_fib: False
#         pc_window: 18
#         inc_fractals: True

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_slice(study, params=["emap1", "lags", "learning_rate"]).update_layout(
    font=dict(size=18),  # Change this to your desired size
    title_font=dict(size=20),
    xaxis_title_font=dict(size=16),
    yaxis_title_font=dict(size=16)
)

# %%
optuna.visualization.plot_param_importances(study).update_layout(
    font=dict(size=18),  # Change this to your desired size
    title_font=dict(size=20),
    xaxis_title_font=dict(size=16),
    yaxis_title_font=dict(size=16)
)

# %%
# Plot

# from sklearn.linear_model import LogisticRegression


# 1. Initialize something to store results in
results = {}

optuna.visualization.plot_optimization_history(study)

# plt.plot(train[-100:], label="Train")
# plt.plot(test.index, test, label="Test")
# plt.plot(test.index, predictions, label="Prediction")
# plt.legend()
# plt.title("XGBoost with Skforecast")
# plt.show()
